# %% [markdown]
# ### Video Indexer API Samples (Python)

# %% [markdown]
# This notebook provides samples for the following operations in Video Indexer:
#
# (1) Get account details.
# (2) Upload a video from URL.
# (2A) Upload a video from local file.
# (3) Wait for the video to finish indexing.
# (4) Search for video and get insights.
# (5) Use the Widgets API.
#
# Make sure you're logged-in with `az` to authenticate your account.
#
# Copy the `.env.example` file to a new file named `.env`, and update the values with your own account settings.

# %%
# imports
from dotenv import dotenv_values
from pprint import pprint

from VideoIndexerClient.Consts import Consts
from VideoIndexerClient.VideoIndexerClient import VideoIndexerClient

# %% [markdown]
# Define the following parameters based on your account settings, in case they are different or not defined as environment variables:

# %%
config = dotenv_values(".env")

AccountName = config.get('AccountName')
ResourceGroup = config.get('ResourceGroup')
SubscriptionId = config.get('SubscriptionId')

ApiVersion = '2024-01-01'
ApiEndpoint = 'https://api.videoindexer.ai'
AzureResourceManager = 'https://management.azure.com'

# create and validate consts
consts = Consts(ApiVersion, ApiEndpoint, AzureResourceManager, AccountName, ResourceGroup, SubscriptionId)

# %%
# Authenticate

# create Video Indexer Client
client = VideoIndexerClient()

# Get access tokens (arm and Video Indexer account)
client.authenticate_async(consts)

# %% [markdown]
# #### Sample 1 - Get Account Basic Details
# Get account details, not required in most cases.

# %%
client.get_account_async()
# Out:
# [Account Details] Id:43844c97-2240-400a-98a0-6674a9587014, Location: eastus

# %% [markdown]
# #### Sample 2 - Index a Video from URL
# Upload a video from URL, do not wait for the index operation to complete.
# Define `videoUrl` and `ExcludedAI` first.
# `ExcludedAI` - A list of the AIs you would like to exclude in the format `['Faces', 'Labels', 'Emotions','ObservedPeople']`. Leave empty if you do not want to exclude any AIs. For more details see [here](https://api-portal.videoindexer.ai/api-details#api=Operations&operation=Upload-Video:~:text=AI%20to%20exclude%20when%20indexing%2C%20for%20example%20for%20sensitive%20scenarios.%20Options%20are%3A%20Face/Observed%20peopleEmotions/Labels%7D).

# %% [markdown]
# #### Sample 2A - Index a Video From File
# Upload From Local File.
# Define `LocalVideoPath` first.

# %%
LocalVideoPath = '/Users/karin.brisker/kinderguard/resources/responsible_ai.mp4'
# excluded_ai = ['Faces', 'OCR', 'Brands', 'Labels', 'NamedLocations', 'NamedPeople', 'Shots']
excluded_ai = ['Faces', 'Labels', 'ObservedPeople']
language_code = 'he-IL'
file_video_id = client.file_upload_async(LocalVideoPath, video_name=None, excluded_ai=excluded_ai, language_code=language_code, indexing_preset='AdvancedAudio')
print(file_video_id)
# Out:
# Uploading a local file using multipart/form-data post request..
# 3i36ju6qq6

# %% [markdown]
# #### Sample 3 - Polling on Video Completion Event
# Wait for the video index to finish (Polling method).

# %%
client.wait_for_index_async(file_video_id)
# Out:
# Checking if video 3i36ju6qq6 has finished indexing...
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index has completed. Here is the full JSON of the index for video ID 3i36ju6qq6:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '43844c97-2240-400a-98a0-6674a9587014', 'id': '3i36ju6qq6', 'name': 'responsible_ai 222 copy 19', 'userName': 'Karin Brisker', 'created': '2024-07-08T11:37:21.6933333+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 114, 'duration': '0:01:54.173', 'summarizedInsights': {'name': 'responsible_ai 222 copy 19', 'id': '3i36ju6qq6', 'privacyMode': 'Private', 'duration': {'time': '0:01:54.173', 'seconds': 114.2}, 'thumbnailVideoId': '3i36ju6qq6', 'thumbnailId': 'f6c2fa69-c984-4f2c-bb10-dd86aff787e2', 'faces': [], 'keywords': [{'isTranscript': True, 'id': 1, 'name': 'Sewage testing', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:01.75', 'startSeconds': 60.8, 'endSeconds': 61.8}]}], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 1, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:01:54.173', 'startSeconds': 0, 'endSeconds': 114.2}]}], 'emotions': [], 'audioEffects': [], 'labels': [], 'framePatterns': [], 'brands': [], 'namedLocations': [{'referenceId': None, 'referenceUrl': None, 'confidence': 1, 'description': None, 'seenDuration': 2.3, 'id': 1, 'name': 'Castamar', 'appearances': [{'startTime': '0:01:44.03', 'endTime': '0:01:46.31', 'startSeconds': 104, 'endSeconds': 106.3}]}], 'namedPeople': [], 'statistics': {'correspondenceCount': 0, 'speakerTalkToListenRatio': {'1': 1}, 'speakerLongestMonolog': {'1': 3}, 'speakerNumberOfFragments': {'1': 2}, 'speakerWordCount': {'1': 5}}, 'topics': [{'referenceUrl': None, 'iptcName': 'environment', 'iabName': 'Environment', 'confidence': 0.9032, 'id': 1, 'name': 'Environment', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/natural resources/water', 'iabName': 'Environment', 'confidence': 0.8157, 'id': 2, 'name': 'Environment/The Environment/Water', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/nature/ecosystem', 'iabName': 'Environment', 'confidence': 0.7933, 'id': 3, 'name': 'Environment/The Environment', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.7355, 'id': 4, 'name': 'Environment/The Environment/Waste Management', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.5589, 'id': 6, 'name': 'Environment/The Environment/Waste Materials', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.5276, 'id': 7, 'name': 'Environment/The Environment/Wastewater', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.52, 'id': 8, 'name': 'Environment/The Environment/Waste Collection', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'health/public health', 'iabName': 'Medical Health', 'confidence': 0.5128, 'id': 9, 'name': 'Health and Wellbeing/Health', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'economy, business and finance/economic  ...

# %% [markdown]
# #### Sample 4 - Get the Video insights
# Get the video insights.

# %%
insights = client.get_video_async(file_video_id)
pprint(insights)
# Out:
# Searching videos in account 43844c97-2240-400a-98a0-6674a9587014 for video ID 3i36ju6qq6.
# Here are the search results:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '43844c97-2240-400a-98a0-6674a9587014', 'id': '3i36ju6qq6', 'name': 'responsible_ai 222 copy 19', 'userName': 'Karin Brisker', 'created': '2024-07-08T11:37:21.6933333+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 114, 'duration': '0:01:54.173', 'summarizedInsights': {'name': 'responsible_ai 222 copy 19', 'id': '3i36ju6qq6', 'privacyMode': 'Private', 'duration': {'time': '0:01:54.173', 'seconds': 114.2}, 'thumbnailVideoId': '3i36ju6qq6', 'thumbnailId': 'f6c2fa69-c984-4f2c-bb10-dd86aff787e2', 'faces': [], 'keywords': [{'isTranscript': True, 'id': 1, 'name': 'ביוב טסטינג', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:01.75', 'startSeconds': 60.8, 'endSeconds': 61.8}]}], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 1, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:01:54.173', 'startSeconds': 0, 'endSeconds': 114.2}]}], 'emotions': [], 'audioEffects': [], 'labels': [], 'framePatterns': [], 'brands': [], 'namedLocations': [{'referenceId': None, 'referenceUrl': None, 'confidence': 1, 'description': None, 'seenDuration': 2.3, 'id': 1, 'name': 'Castamar', 'appearances': [{'startTime': '0:01:44.03', 'endTime': '0:01:46.31', 'startSeconds': 104, 'endSeconds': 106.3}]}], 'namedPeople': [], 'statistics': {'correspondenceCount': 0, 'speakerTalkToListenRatio': {'1': 1}, 'speakerLongestMonolog': {'1': 3}, 'speakerNumberOfFragments': {'1': 2}, 'speakerWordCount': {'1': 5}}, 'topics': [{'referenceUrl': None, 'iptcName': 'environment', 'iabName': 'Environment', 'confidence': 0.9032, 'id': 1, 'name': 'סביבה', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/natural resources/water', 'iabName': 'Environment', 'confidence': 0.8157, 'id': 2, 'name': 'סביבה/איכות הסביבה/מים', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/nature/ecosystem', 'iabName': 'Environment', 'confidence': 0.7933, 'id': 3, 'name': 'סביבה/איכות הסביבה', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.7355, 'id': 4, 'name': 'סביבה/איכות הסביבה/טיפול בפסולת', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.5589, 'id': 6, 'name': 'סביבה/איכות הסביבה/חומרי פסולת', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.5276, 'id': 7, 'name': 'סביבה/איכות הסביבה/שפכים', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'environment/environmental pollution/waste materials', 'iabName': 'Environment', 'confidence': 0.52, 'id': 8, 'name': 'סביבה/איכות הסביבה/איסוף פסולת', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'health/public health', 'iabName': 'Medical Health', 'confidence': 0.5128, 'id': 9, 'name': 'בריאות ורווחה/בריאות', 'appearances': [{'startTime': '0:01:00.75', 'endTime': '0:01:46.31', 'startSeconds': 60.8, 'endSeconds': 106.3}]}, {'referenceUrl': None, 'iptcName': 'economy, business and finance/economic sector/consumer goods/beverage', 'iabName': 'Food & Drink', 'confidence': 0.5087, 'id': 10 ...
# {'accountId': '43844c97-2240-400a-98a0-6674a9587014',
#  'created': '2024-07-08T11:37:21.6933333+00:00',
#  'description': None,
#  'duration': '0:01:54.173',
#  'durationInSeconds': 114,
#  'id': '3i36ju6qq6',
#  'isBase': True,
#  'isEditable': True,
#  'isOwned': True,
#  'name': 'responsible_ai 222 copy 19',
#  'partition': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'summarizedInsights': {'audioEffects': [],
#                         'brands': [],
#                         'duration': {'seconds': 114.2, 'time': '0:01:54.173'},
#                         'emotions': [],
#                         'faces': [],
#                         'framePatterns': [],
#                         'id': '3i36ju6qq6',
#                         'keywords': [{'appearances': [{'endSeconds': 61.8,
#                                                        'endTime': '0:01:01.75',
#                                                        'startSeconds': 60.8,
#                                                        'startTime': '0:01:00.75'}],
#                                       'id': 1,
#                                       'isTranscript': True,
#                                       'name': 'ביוב טסטינג'}],
#                         'labels': [],
#                         'name': 'responsible_ai 222 copy 19',
#                         'namedLocations': [{'appearances': [{'endSeconds': 106.3,
#                                                              'endTime': '0:01:46.31',
#                                                              'startSeconds': 104,
#                                                              'startTime': '0:01:44.03'}],
#                                             'confidence': 1,
#                                             'description': None,
#                                             'id': 1,
#                                             'name': 'Castamar',
#                                             'referenceId': None,
#                                             'referenceUrl': None,
#                                             'seenDuration': 2.3}],
#                         'namedPeople': [],
#                         'privacyMode': 'Private',
#                         'sentiments': [{'appearances': [{'endSeconds': 114.2,
#                                                          'endTime': '0:01:54.173',
#                                                          'startSeconds': 0,
#                                                          'startTime': '0:00:00'}],
#                                         'seenDurationRatio': 1,
#                                         'sentimentKey': 'Neutral'}],
#                         'statistics': {'correspondenceCount': 0,
#                                        'speakerLongestMonolog': {'1': 3},
#                                        'speakerNumberOfFragments': {'1': 2},
#                                        'speakerTalkToListenRatio': {'1': 1},
#                                        'speakerWordCount': {'1': 5}},
#                         'thumbnailId': 'f6c2fa69-c984-4f2c-bb10-dd86aff787e2',
#                         'thumbnailVideoId': '3i36ju6qq6',
#                         'topics': [{'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.9032,
#                                     'iabName': 'Environment',
#                                     'id': 1,
#                                     'iptcName': 'environment',
#                                     'name': 'סביבה',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.8157,
#                                     'iabName': 'Environment',
#                                     'id': 2,
#                                     'iptcName': 'environment/natural '
#                                                 'resources/water',
#                                     'name': 'סביבה/איכות הסביבה/מים',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.7933,
#                                     'iabName': 'Environment',
#                                     'id': 3,
#                                     'iptcName': 'environment/nature/ecosystem',
#                                     'name': 'סביבה/איכות הסביבה',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.7355,
#                                     'iabName': 'Environment',
#                                     'id': 4,
#                                     'iptcName': 'environment/environmental '
#                                                 'pollution/waste materials',
#                                     'name': 'סביבה/איכות הסביבה/טיפול בפסולת',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.5589,
#                                     'iabName': 'Environment',
#                                     'id': 6,
#                                     'iptcName': 'environment/environmental '
#                                                 'pollution/waste materials',
#                                     'name': 'סביבה/איכות הסביבה/חומרי פסולת',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.5276,
#                                     'iabName': 'Environment',
#                                     'id': 7,
#                                     'iptcName': 'environment/environmental '
#                                                 'pollution/waste materials',
#                                     'name': 'סביבה/איכות הסביבה/שפכים',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.52,
#                                     'iabName': 'Environment',
#                                     'id': 8,
#                                     'iptcName': 'environment/environmental '
#                                                 'pollution/waste materials',
#                                     'name': 'סביבה/איכות הסביבה/איסוף פסולת',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.5128,
#                                     'iabName': 'Medical Health',
#                                     'id': 9,
#                                     'iptcName': 'health/public health',
#                                     'name': 'בריאות ורווחה/בריאות',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.5087,
#                                     'iabName': 'Food & Drink',
#                                     'id': 10,
#                                     'iptcName': 'economy, business and '
#                                                 'finance/economic '
#                                                 'sector/consumer '
#                                                 'goods/beverage',
#                                     'name': 'מזון ומשקאות/משקאות/שתייה',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.5071,
#                                     'iabName': 'Real Estate',
#                                     'id': 11,
#                                     'iptcName': 'economy, business and '
#                                                 'finance/economic '
#                                                 'sector/construction and '
#                                                 'property/heavy construction',
#                                     'name': 'נדל"ן/בנייה',
#                                     'referenceUrl': None},
#                                    {'appearances': [{'endSeconds': 106.3,
#                                                      'endTime': '0:01:46.31',
#                                                      'startSeconds': 60.8,
#                                                      'startTime': '0:01:00.75'}],
#                                     'confidence': 0.5036,
#                                     'iabName': 'Science',
#                                     'id': 12,
#                                     'iptcName': 'science and technology',
#                                     'name': 'מדע',
#                                     'referenceUrl': None}]},
#  'userName': 'Karin Brisker',
#  'videos': [{'accountId': '43844c97-2240-400a-98a0-6674a9587014',
#              'detectSourceLanguage': False,
#              'excludedAIs': ['Labels'],
#              'externalId': None,
#              'externalUrl': None,
#              'failureMessage': '',
#              'id': '3i36ju6qq6',
#              'indexingPreset': 'AdvancedAudio',
#              'insights': {'blocks': [{'id': 0,
#                                       'instances': [{'adjustedEnd': '0:01:01.75',
#                                                      'adjustedStart': '0:00:00',
#                                                      'end': '0:01:01.75',
#                                                      'start': '0:00:00'}]},
#                                      {'id': 1,
#                                       'instances': [{'adjustedEnd': '0:01:54.173',
#                                                      'adjustedStart': '0:01:01.75',
#                                                      'end': '0:01:54.173',
#                                                      'start': '0:01:01.75'}]}],
#                           'duration': '0:01:54.173',
#                           'keywords': [{'confidence': 0.9847,
#                                         'id': 1,
#                                         'instances': [{'adjustedEnd': '0:01:01.75',
#                                                        'adjustedStart': '0:01:00.75',
#                                                        'end': '0:01:01.75',
#                                                        'start': '0:01:00.75'}],
#                                         'language': 'he-IL',
#                                         'text': 'ביוב טסטינג'}],
#                           'language': 'he-IL',
#                           'languages': ['he-IL'],
#                           'namedLocations': [{'confidence': 1,
#                                               'description': None,
#                                               'id': 1,
#                                               'instances': [{'adjustedEnd': '0:01:46.31',
#                                                              'adjustedStart': '0:01:44.03',
#                                                              'end': '0:01:46.31',
#                                                              'instanceSource': 'Transcript',
#                                                              'start': '0:01:44.03'}],
#                                               'isCustom': False,
#                                               'name': 'Castamar',
#                                               'referenceId': None,
#                                               'referenceUrl': None,
#                                               'tags': []}],
#                           'sentiments': [{'averageScore': 0.5,
#                                           'id': 1,
#                                           'instances': [{'adjustedEnd': '0:01:54.173',
#                                                          'adjustedStart': '0:00:00',
#                                                          'end': '0:01:54.173',
#                                                          'start': '0:00:00'}],
#                                           'sentimentType': 'Neutral'}],
#                           'sourceLanguage': 'he-IL',
#                           'sourceLanguages': ['he-IL'],
#                           'speakers': [{'id': 1,
#                                         'instances': [{'adjustedEnd': '0:01:01.75',
#                                                        'adjustedStart': '0:01:00.75',
#                                                        'end': '0:01:01.75',
#                                                        'start': '0:01:00.75'},
#                                                       {'adjustedEnd': '0:01:46.31',
#                                                        'adjustedStart': '0:01:44.03',
#                                                        'end': '0:01:46.31',
#                                                        'start': '0:01:44.03'}],
#                                         'name': 'Speaker #1'}],
#                           'statistics': {'correspondenceCount': 0,
#                                          'speakerLongestMonolog': {'1': 3},
#                                          'speakerNumberOfFragments': {'1': 2},
#                                          'speakerTalkToListenRatio': {'1': 1},
#                                          'speakerWordCount': {'1': 5}},
#                           'textualContentModeration': {'bannedWordsCount': 0,
#                                                        'bannedWordsRatio': 0,
#                                                        'id': 0,
#                                                        'instances': []},
#                           'topics': [{'confidence': 0.9032,
#                                       'fullName': 'סביבה',
#                                       'iabName': 'Environment',
#                                       'id': 1,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment',
#                                       'language': 'he-IL',
#                                       'name': 'סביבה',
#                                       'referenceId': 'Environment',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.8157,
#                                       'fullName': 'סביבה/איכות הסביבה/מים',
#                                       'iabName': 'Environment',
#                                       'id': 2,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment/natural '
#                                                   'resources/water',
#                                       'language': 'he-IL',
#                                       'name': 'מים',
#                                       'referenceId': 'Environment/The '
#                                                      'Environment/Water',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.7933,
#                                       'fullName': 'סביבה/איכות הסביבה',
#                                       'iabName': 'Environment',
#                                       'id': 3,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment/nature/ecosystem',
#                                       'language': 'he-IL',
#                                       'name': 'איכות הסביבה',
#                                       'referenceId': 'Environment/The '
#                                                      'Environment',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.7355,
#                                       'fullName': 'סביבה/איכות הסביבה/טיפול '
#                                                   'בפסולת',
#                                       'iabName': 'Environment',
#                                       'id': 4,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment/environmental '
#                                                   'pollution/waste materials',
#                                       'language': 'he-IL',
#                                       'name': 'טיפול בפסולת',
#                                       'referenceId': 'Environment/The '
#                                                      'Environment/Waste '
#                                                      'Management',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.7328,
#                                       'fullName': 'סביבה/איכות הסביבה/איכות '
#                                                   'הסביבה',
#                                       'iabName': 'Environment',
#                                       'id': 5,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment/climate change',
#                                       'language': 'he-IL',
#                                       'name': 'איכות הסביבה',
#                                       'referenceId': 'Environment/The '
#                                                      'Environment/Environmentalism',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.5589,
#                                       'fullName': 'סביבה/איכות הסביבה/חומרי '
#                                                   'פסולת',
#                                       'iabName': 'Environment',
#                                       'id': 6,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment/environmental '
#                                                   'pollution/waste materials',
#                                       'language': 'he-IL',
#                                       'name': 'חומרי פסולת',
#                                       'referenceId': 'Environment/The '
#                                                      'Environment/Waste '
#                                                      'Materials',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.5276,
#                                       'fullName': 'סביבה/איכות הסביבה/שפכים',
#                                       'iabName': 'Environment',
#                                       'id': 7,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment/environmental '
#                                                   'pollution/waste materials',
#                                       'language': 'he-IL',
#                                       'name': 'שפכים',
#                                       'referenceId': 'Environment/The '
#                                                      'Environment/Wastewater',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.52,
#                                       'fullName': 'סביבה/איכות הסביבה/איסוף '
#                                                   'פסולת',
#                                       'iabName': 'Environment',
#                                       'id': 8,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'environment/environmental '
#                                                   'pollution/waste materials',
#                                       'language': 'he-IL',
#                                       'name': 'איסוף פסולת',
#                                       'referenceId': 'Environment/The '
#                                                      'Environment/Waste '
#                                                      'Collection',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.5128,
#                                       'fullName': 'בריאות ורווחה/בריאות',
#                                       'iabName': 'Medical Health',
#                                       'id': 9,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'health/public health',
#                                       'language': 'he-IL',
#                                       'name': 'בריאות',
#                                       'referenceId': 'Health and '
#                                                      'Wellbeing/Health',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.5087,
#                                       'fullName': 'מזון ומשקאות/משקאות/שתייה',
#                                       'iabName': 'Food & Drink',
#                                       'id': 10,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'economy, business and '
#                                                   'finance/economic '
#                                                   'sector/consumer '
#                                                   'goods/beverage',
#                                       'language': 'he-IL',
#                                       'name': 'שתייה',
#                                       'referenceId': 'Food and '
#                                                      'Drink/Beverages/Drinking '
#                                                      'Water',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.5071,
#                                       'fullName': 'נדל"ן/בנייה',
#                                       'iabName': 'Real Estate',
#                                       'id': 11,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'economy, business and '
#                                                   'finance/economic '
#                                                   'sector/construction and '
#                                                   'property/heavy construction',
#                                       'language': 'he-IL',
#                                       'name': 'בנייה',
#                                       'referenceId': 'Real Estate/Construction',
#                                       'referenceType': 'VideoIndexer'},
#                                      {'confidence': 0.5036,
#                                       'fullName': 'מדע',
#                                       'iabName': 'Science',
#                                       'id': 12,
#                                       'instances': [{'adjustedEnd': '0:01:46.31',
#                                                      'adjustedStart': '0:01:00.75',
#                                                      'end': '0:01:46.31',
#                                                      'start': '0:01:00.75'}],
#                                       'iptcName': 'science and technology',
#                                       'language': 'he-IL',
#                                       'name': 'מדע',
#                                       'referenceId': 'Science',
#                                       'referenceType': 'VideoIndexer'}],
#                           'transcript': [{'confidence': 0.3733,
#                                           'id': 1,
#                                           'instances': [{'adjustedEnd': '0:01:01.75',
#                                                          'adjustedStart': '0:01:00.75',
#                                                          'end': '0:01:01.75',
#                                                          'start': '0:01:00.75'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 1,
#                                           'text': 'ביוב טסטינג.'},
#                                          {'confidence': 0.2217,
#                                           'id': 2,
#                                           'instances': [{'adjustedEnd': '0:01:46.31',
#                                                          'adjustedStart': '0:01:44.03',
#                                                          'end': '0:01:46.31',
#                                                          'start': '0:01:44.03'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 1,
#                                           'text': "קאסטמר אייג' אנדס."}],
#                           'version': '1.0.0.0'},
#              'isAdult': False,
#              'language': 'he-IL',
#              'languageAutoDetectMode': 'None',
#              'languages': ['he-IL'],
#              'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#              'logoGroupId': None,
#              'metadata': None,
#              'moderationState': 'OK',
#              'personModelId': '00000000-0000-0000-0000-000000000000',
#              'privacyMode': 'Private',
#              'processingProgress': '100%',
#              'publishedProxyUrl': None,
#              'publishedUrl': 'https://api.videoindexer.ai/internals/eastus/Accounts/43844c97-2240-400a-98a0-6674a9587014/Videos/3i36ju6qq6/streaming-manifest/manifest.m3u8',
#              'reviewState': 'None',
#              'sourceLanguage': 'he-IL',
#              'sourceLanguages': ['he-IL'],
#              'state': 'Processed',
#              'streamingPreset': 'Default',
#              'thumbnailId': 'f6c2fa69-c984-4f2c-bb10-dd86aff787e2',
#              'viewToken': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....p9czWskp5p4Z30zS1Zd4_JartPr-jSXUn_cWiwGYp_cRZmdu1X8Y1_l_BYdwCVxUDlxN-N_2wMVjkdQZDqP-v8XFcXKvLXiUcv-ptpoxX4UoxTPthOO4W011pzKSsMxLHJzN2RUgmhlrJnCuDb6SWuOL4fwJb6dx3HQbtFY303ef7dT1AwIvQlZKinEgJRCaUmi0dXPg7irlppaNkYkeR4FvRfgb-OdRlm94IBuoDDbpxDgiZAtzU9ShRD29KHsO9sjf_B6_axur7Dqyqe8ibnPizwG5d8Qi06-w81hW5Ag-dkERDTL6DggTOwiGKAIp4pMITL1JMwXQRdz6yb_U0w'}],
#  'videosRanges': [{'range': {'end': '0:01:54.173', 'start': '0:00:00'},
#                    'videoId': '3i36ju6qq6'}]}

# %% [markdown]
# #### Sample 5 - Widgets API

# %%
client.get_insights_widgets_url_async(file_video_id, widget_type='audioEffects')
client.get_player_widget_url_async(file_video_id)
# Out:
# Getting the insights widget URL for video 3i36ju6qq6
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 client.get_insights_widgets_url_async(file_video_id, widget_type='audioEffects')
#       2 client.get_player_widget_url_async(file_video_id)
#
# File ~/kinderguard/azure-video-indexer-samples/API-Samples/Python/VideoIndexerClient/VideoIndexerClient.py:368, in VideoIndexerClient.get_insights_widgets_url_async(self, video_id, widget_type, allow_edit)
#     363 url = f'{self.consts.ApiEndpoint}/{self.account["location"]}/Accounts/{self.account["properties"]["accountId"]}/' + \
#     364       f'Videos/{video_id}/InsightsWidget'
#     366 response = requests.get(url, params=params)
# --> 368 response.raise_for_status()
#     370 insights_widget_url = response.url
#     371 print(f'Got the insights widget URL: {insights_widget_url}')
#
# File ~/opt/anaconda3/envs/videoindexer/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.videoindexer.ai/eastus/Accounts/43844c97-2240-400a-98a0-6674a9587014/Videos/3i36ju6qq6/InsightsWidget?widgetType=audioEffects&allowEdit=false&accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....spIdp4Ei7uV5qq24F0UFJQB_KwDVJlZVAHROfJQ4aC2tkDnnVVdWhY9erR_eLwTYX0UtXlLyMMi_okmy6a1o9N_FHWVy7Mi1ybuas8JfCNiJ2XnVuJmmfLwP7u8TgQ_0LFDL_9KtGREBCdV8AlYHWappAZqrGAKP_TWM0u4Ed8HuvOVBKWtJoW3LaSzeL3pQElqWVvwDdkuQVSWJ2M4RHZEIarsAaItiFWCLWlrq_FRRGOkDm97wUJlONbMbM8ICi6tRnvUI_URt7X1odd6I0-2KQ_SK0Q4lp1TpgxUengXau7tclG3AhciCc0U1jJM_HruVQJiS_n1QsD5j__0KLw

# %% [markdown]
# #### Sample 6 - Prompt Content API

# %%
prompt_content = client.get_prompt_content(file_video_id)
pprint(prompt_content)
# Out:
# Prompt content generation for video_id='8r3kil0qj5' started...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# {'name': 'responsible_ai 222 copy 18',
#  'partition': None,
#  'sections': [{'content': '[Video title] responsible_ai 222 copy 18\n'
#                           '[Detected objects] airplane, book, car, cell phone, '
#                           'chair, couch, cup, laptop\n'
#                           '[Visual labels] device, cloud, sky, clothing, '
#                           'person, human face, outdoor, building, tree, man, '
#                           'machine, woman, shirt, chin, forehead, watch, '
#                           'finger, wrist, indoor, wall, furniture, house, '
#                           'computer, smile, grass\n'
#                           '[OCR] The, potential, For the, benefit of, '
#                           'everyone, Machines, Move into, Roles, of Humans, '
#                           'Eric Horvitz, Chief Scientific Officer, Microsoft, '
#                           'Natasha Crampton, Chief Responsible Al Officer, '
#                           'FAIRNESS, RELIABILITY, & SAFETY, INCLUSIVENESS, '
#                           'PRIVACY, & SECURITY, ACCOUNTABILITY, TRANSPARENCY, '
#                           'OFFICE OF, RESPONSIBLE, AETHER, COMMITTEE, '
#                           'INNOVATION, Loan Application:, Debt, Income, '
#                           'Credit, Assets, commitments, DENIED, Johnsm, '
#                           'Password, er me\n'
#                           '[Transcript] We believe in the potential of AI to '
#                           'improve our lives in big and small ways.\n'
#                           "We need to make sure it's for the benefit of "
#                           'everyone.\n'
#                           "For the first time, we're having machines moved "
#                           'into roles that have been the roles of human '
#                           'beings.\n'
#                           'Might these technologies have inadvertent effects '
#                           'on people and society?\n'
#                           "Do they align with people's values, their ethics?\n"
#                           'We needed to think through the implications for our '
#                           'company.\n'
#                           'Responsible AI is the approach that we take to '
#                           'developing and deploying our technology, making '
#                           'sure our principles are brought to life and that it '
#                           'empowers everyone and is inclusive and accessible '
#                           'for people.\n'
#                           'Excellent.\n'
#                           'The job of the Office of Responsible AI is to put '
#                           'our principles into practice by operationalizing '
#                           'ethics across the company.\n'
#                           'The Ether Committee is responsible for deliberating '
#                           'about hard new questions.\n'
#                           'We are sister We have to think through what it '
#                           'means to detect bias, make our systems more fair, '
#                           'to detect errors and blind spots in our '
#                           'technologies, and on thinking through the kinds of '
#                           'advice we give to other organizations on to our '
#                           'leaders.\n'
#                           'Where technology can impose on privacy and human '
#                           'rights.\n'
#                           'Responsibility is at the core.\n'
#                           "We're learning everyday about this new role of "
#                           'responsible computing.',
#                'end': '0:01:24.918167',
#                'id': 0,
#                'start': '0:00:00'},
#               {'content': '[Video title] responsible_ai 222 copy 18\n'
#                           '[Detected objects] boat, chair, laptop, potted '
#                           'plant\n'
#                           '[Visual labels] clothing, person, human face, '
#                           'shirt, display, man, indoor, wall, computer, '
#                           'laptop, office building, personal computer, output '
#                           'device, desktop computer, computer hardware, '
#                           'computer keyboard, medical equipment, medical, '
#                           'healthcare, laboratory equipment, medical glove, '
#                           'sky, outdoor, water, transport, watercraft, naval '
#                           'architecture, smile, map, eyebrow\n'
#                           '[OCR] 32, 33, 35, 92, 93, 94, 95, 96, 97, 98, int x '
#                           '= 0;, // now verticical stripe the pixels for each '
#                           'panel., // walk the map backwards., unsigned int '
#                           'outByte = 0x00; // the vertical stripe, for (y =0; '
#                           'y < 7; y++), int bytePos = x / 8; // get the byte '
#                           'offset for this, int bitPos = x % 8; // get the bit '
#                           'offset for this str, int buffPos = (y *4) + '
#                           'bytePos;, unsigned int bByte = bFlipDisp[(28 * '
#                           'tray) + buffPos], unsigned int iSet = bByte & '
#                           'getMask[bitPos];, if (iSet != 0), outByte |= '
#                           'setMask[y];, SURVIVOR, EXTINGUISHER, VESSEL: '
#                           'UNLICENSED, 15, Microsoft, ROC Interface\n'
#                           '[Transcript] We need to translate academic thought '
#                           'to language that our engineers and sales people are '
#                           'familiar with.\n'
#                           'Our customers are grappling with many of the same '
#                           'issues.\n'
#                           "It's incumbent on us to share what we learn.\n"
#                           "It's about trying to do better every day, working "
#                           'with our customers and outside agencies to develop '
#                           'processes and deliver responsible computing '
#                           'technologies to the world.',
#                'end': '0:01:54.114',
#                'id': 1,
#                'start': '0:01:24.918167'}]}
